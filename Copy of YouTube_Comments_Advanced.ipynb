# %%
dev = "AIzaSyB_f3uROqZfwBWsc_sDEV63WmUHBgvGGqw"

# %% [markdown]
# ## Pull All Comments

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="URETZEVl0WY",
    maxResults=2036
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="URETZEVl0WY", maxResults=460, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9212 entries, 0 to 9211
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      9212 non-null   object
#  1   updated_at  9212 non-null   object
#  2   like_count  9212 non-null   int64
#  3   text        9212 non-null   object
#  4   public      9212 non-null   bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 297.0+ KB

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': '5Ry_Qs2DMUUFwrd-RqHdQDx4NHA',
#  'id': 'Ugxw7SzMFletChZOlb14AaABAg',
#  'snippet': {'channelId': 'UCUbtdbJRpaXiUI_IlBOvPpA',
#   'videoId': 'URETZEVl0WY',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'IyWz-2zQ_mGb_g6wCKZKsFkU3Gw',
#    'id': 'Ugxw7SzMFletChZOlb14AaABAg',
#    'snippet': {'channelId': 'UCUbtdbJRpaXiUI_IlBOvPpA',
#     'videoId': 'URETZEVl0WY',
#     'textDisplay': 'প্রথম কমেন্ট',
#     'textOriginal': 'প্রথম কমেন্ট',
#     'authorDisplayName': '@imok6263',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l3vzlfGh_cUsmWmfgCYfl0CgR7wJ1YTo-K1BXFd5l8VL26rm1vYx6UYO5ILEs2NcGMpw=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@imok6263',
#     'authorChannelId': {'value': 'UCJVC55UeEPLhMQjCXj5rvjQ'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2025-01-30T13:12:36Z',
#     'updatedAt': '2025-01-30T13:12:36Z'}},
# ...

# %%
df.head(10)
# Out:
#                 author            updated_at  like_count  \
# 0   @nazmulhossain6353  2025-02-04T19:04:21Z           0
# 1  @jahangiralomsylhet  2025-02-04T18:50:53Z           0
# 2      @AnikaIslam-e5x  2025-02-04T18:48:31Z           0
# 3      @TouhdbdSheebdb  2025-02-04T18:44:54Z           0
# 4      @AnikaIslam-e5x  2025-02-04T18:31:57Z           0
# 5       @Md.AlifurReza  2025-02-04T18:31:23Z           0
# 6       @Md.AlifurReza  2025-02-04T18:29:37Z           0
# 7    @shimulhassan1991  2025-02-04T17:45:25Z           0
# 8            @chayanbd  2025-02-04T16:10:31Z           0
# 9     @biplobhasan6875  2025-02-04T15:53:31Z           0
#
#                                                 text  public
# 0                                          অসাধারণ ❤    True
# 1  পিনাকী দা যে যে উদ্যোগ নিতে বলছেন ,  সম্মানিত ...    True
# 2                        কি দেশে জন্মাইলাম আল্লাহ। 😢    True
# 3                                Keeeeeeeenoooooooo😂    True
# ...

# %% [markdown]
# ## Sort by Likes and Get Top 10

# %%
df.sort_values(by='like_count', ascending=False)[0:10]

# %% [markdown]
# #Pull all Comments for Multiple Videos

# %% [markdown]
# ## 1. Get Comments Function

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)


def getcomments(video):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video,
      maxResults=540
  )

  comments = []

  # Execute the request.
  response = request.execute()

  # Get the comments from the response.
  for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  while (1 == 1):
    try:
     nextPageToken = response['nextPageToken']
    except KeyError:
     break
    nextPageToken = response['nextPageToken']
    # Create a new request object with the next page token.
    nextRequest = youtube.commentThreads().list(part="snippet", videoId=video, maxResults=540, pageToken=nextPageToken)
    # Execute the next request.
    response = nextRequest.execute()
    # Get the comments from the next response.
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  df2 = pd.DataFrame(comments, columns=['author','text','video_id','public'])
  return df2

# %%
df = getcomments('W8dfTMysWfY')
df
# Out:
#                      author  \
# 0        @HarunRashid-jl2xl
# 1             @RaselMia-k8c
# 2         @kalamkhalifa-t3g
# 3   @khandokersalauddin9906
# 4     @sarminakterjuthi4067
# ..                      ...
# 69    @commodusmeridius4718
# 70        @EmdadulHasan-g2x
# 71        @sadequeahmed7153
# 72         @romanparvez-j2u
# 73        @RubelHasan-cm1px
#
#                                                  text     video_id  public
# 0                              মিথ্যা তথ্য দিচ্ছ কেন?  W8dfTMysWfY    True
# 1                                    পাগল কত কিছু বলে  W8dfTMysWfY    True
# 2                  আসিফ নজরুল একেবারে মিথ্যা কথা বলছে  W8dfTMysWfY    True
# 3   মিডিয়ার খবর বিশ্বাস করলে ঈমান টিকানো কষ্টকর হয়...  W8dfTMysWfY    True
# 4                                         চাম চা টিভি  W8dfTMysWfY    True
# ..                                                ...          ...     ...
# 69              ????? That's why don't trust any news  W8dfTMysWfY    True
# ...

# %% [markdown]
# ## 2. For Loop for List of IDs

# %%
df = pd.DataFrame()
for i in ['zCiBzXuhhT0','q4F41fCoJ1k','jq--fLYQuP8','W8dfTMysWfY']:
  df2 = getcomments(i)
  df = pd.concat([df, df2])

# %%
df

# %%
df.value_counts()
# Out:
# author                   text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        video_id     public
# ...

# %%
df.head()

# %%
df.to_excel('pinaki_2.xlsx', index=False)
